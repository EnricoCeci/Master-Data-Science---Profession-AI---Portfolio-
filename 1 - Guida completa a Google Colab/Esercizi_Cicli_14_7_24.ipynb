# %% [markdown]
# <a href="https://colab.research.google.com/github/EnricoCeci/Esercizi-Profession-AI/blob/main/Esercizi_Cicli_14_7_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ESERCIZIO N.1: POTENZE

# %%
n = int(input())

if n<1 or n>20:
     print("Il numero deve essere compreso tra 1 e 20")
else:
  for i in range(n):
    print(i**2)
# Out:
# 1
# 0

# %% [markdown]
# ESERCIZIO N.2: SECONDO ARRIVATO

# %% [markdown]
# Soluzione più laboriosa

# %% [markdown]
# ![photo_2024-07-14_16-01-46.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Soluzione meno laboriosa
#
# -Devo ricordare che sort ordina automaticamente in ordine crescente, e quindi per ordinare in ordine decrescente devo fare come nella foto.
#
# In base all'ordine sceglierò l'indice per estrarre il valore che più mi interessa

# %% [markdown]
# ![photo_2024-07-14_16-09-20.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ESERCIZIO N.3: REGISTRO
#
# Vedi video in [Esercitazione Cicli] per tutta spiegazione

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ESERCIZIO N.4: PALINDROMI
#
# Vedi video per spiegazione codice

# %%
word = input()
while word != "stop":
  is_palindrome = True
  word_len = len(word)

  for i in range(word_len):
    j = word_len -1 -i

    if word[i] != word[j]:
      is_palindrome = False
      break

  if is_palindrome:
        print(word, "is a palindrome")
  else:
        print(word, "is not a palindrome")
  word = input()
# Out:
# trota
# trota is not a palindrome
# osso
# osso is a palindrome
# black
# black is not a palindrome
# stop
